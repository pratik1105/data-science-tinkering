# %%
pwd
# Out:
# u'C:\\Users\\Pratik\\Documents'

# %%
cd C:/Users/Pratik/Downloads
# Out:
# C:\Users\Pratik\Downloads

# %%
pwd
# Out:
# u'C:\\Users\\Pratik\\Downloads'

# %%
import pandas as pd
import seaborn as sns

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./character-deaths.csv')

# %%
df.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
death_ch=df[df['Death Chapter'].notnull()]

# %%
death_ch.loc[:,'Death Chapter']=death_ch.loc[:,'Death Chapter'].astype(int)

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='Death Chapter',data=death_ch)

# %%
plt.show()

# %%
death_ch
# Out:
#                                   Name      Allegiances  Death Year  \
# 1              Aegon Frey (Jinglebell)             None       299.0
# 3                        Adrack Humble    House Greyjoy       300.0
# 6    Aemon Targaryen (son of Maekar I)    Night's Watch       300.0
# 10                               Aggar    House Greyjoy       299.0
# 12                       Alan of Rosby    Night's Watch       300.0
# 16                            Alebelly      House Stark       299.0
# 22                     Allard Seaworth        Baratheon       299.0
# 24                                Alyn      House Stark       298.0
# 32                         Amory Lorch  House Lannister       299.0
# 39                           Anvil Ryn             None       299.0
# 47                       Aron Santagar        Lannister       299.0
# 56                       Arys Oakheart        Lannister       300.0
# 63                              Bannen    Night's Watch       299.0
# ...

# %%
death_book=df[df['Book of Death'].notnull()]

# %%
death_book.shape
# Out:
# (307, 13)

# %%
sns.countplot(x='Book of Death',data=death_book)

# %%
plt.show()

# %%
book_intro=df[df['Book Intro Chapter'].notnull()]

# %%
book_intro.shape
# Out:
# (905, 13)

# %%
sns.countplot(x='Book Intro Chapter',data=book_intro)

# %%
plt.show()

# %%
book_intro.loc[:,'Book Intro Chapter']=book_intro.loc[:,'Book Intro Chapter'].astype(int)

# %%
book_intro['Book Intro Chapter'].value_counts()
# Out:
# 0     41
# 2     32
# 19    30
# 38    29
# 37    28
# 11    27
# 22    26
# 1     25
# 34    25
# 29    24
# 7     22
# 6     20
# 49    18
# 41    18
# 18    16
# 55    16
# 12    15
# 16    15
# 42    14
# 59    14
# 14    14
# 26    14
# 21    14
# 5     14
# 30    14
# 10    13
# 43    13
# 23    13
# 35    13
# 3     12
#       ..
# 44     8
# 17     7
# 39     7
# 62     7
# 40     7
# 52     7
# 66     7
# 9      6
# 51     6
# 57     6
# 64     6
# 46     5
# 60     5
# 61     5
# 69     5
# 45     4
# 47     4
# 54     4
# 71     4
# 58     3
# 75     3
# 70     3
# 73     2
# 36     2
# 67     2
# 72     1
# 74     1
# 79     1
# 78     1
# 80     1
# Name: Book Intro Chapter, dtype: int64

# %%
death_book['Gender'].value_counts()
# Out:
# 1    271
# 0     36
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# 1    760
# 0    157
# Name: Gender, dtype: int64

# %%
death_book['Gender'].value_counts()/df['Gender'].value_counts()
# Out:
# 1    0.356579
# 0    0.229299
# Name: Gender, dtype: float64

# %%
36.0/157
# Out:
# 0.22929936305732485
