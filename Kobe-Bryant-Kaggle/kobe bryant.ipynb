# %%
cd C:/Users/Pratik/Desktop
# Out:
# C:\Users\Pratik\Desktop

# %%
pwd
# Out:
# u'C:\\Users\\Pratik\\Desktop'

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('./data.csv')
df.head()
# Out:
#          action_type combined_shot_type  game_event_id   game_id      lat  \
# 0          Jump Shot          Jump Shot             10  20000012  33.9723
# 1          Jump Shot          Jump Shot             12  20000012  34.0443
# 2          Jump Shot          Jump Shot             35  20000012  33.9093
# 3          Jump Shot          Jump Shot             43  20000012  33.8693
# 4  Driving Dunk Shot               Dunk            155  20000012  34.0443
#
#    loc_x  loc_y       lon  minutes_remaining  period   ...          shot_type  \
# 0    167     72 -118.1028                 10       1   ...     2PT Field Goal
# 1   -157      0 -118.4268                 10       1   ...     2PT Field Goal
# 2   -101    135 -118.3708                  7       1   ...     2PT Field Goal
# 3    138    175 -118.1318                  6       1   ...     2PT Field Goal
# 4      0      0 -118.2698                  6       2   ...     2PT Field Goal
#
#           shot_zone_area  shot_zone_basic  shot_zone_range     team_id  \
# 0          Right Side(R)        Mid-Range        16-24 ft.  1610612747
# 1           Left Side(L)        Mid-Range         8-16 ft.  1610612747
# 2   Left Side Center(LC)        Mid-Range        16-24 ft.  1610612747
# 3  Right Side Center(RC)        Mid-Range        16-24 ft.  1610612747
# 4              Center(C)  Restricted Area  Less Than 8 ft.  1610612747
#
#             team_name   game_date    matchup opponent  shot_id
# 0  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        1
# 1  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        2
# 2  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        3
# 3  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        4
# 4  Los Angeles Lakers  2000-10-31  LAL @ POR      POR        5
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (30697, 25)

# %%
not_needed=[]

# %%
df['action_type'].unique()
# Out:
# array(['Jump Shot', 'Driving Dunk Shot', 'Layup Shot', 'Running Jump Shot',
#        'Driving Layup Shot', 'Reverse Layup Shot', 'Reverse Dunk Shot',
#        'Slam Dunk Shot', 'Turnaround Jump Shot', 'Tip Shot',
#        'Running Hook Shot', 'Alley Oop Dunk Shot', 'Dunk Shot',
#        'Alley Oop Layup shot', 'Running Dunk Shot',
#        'Driving Finger Roll Shot', 'Running Layup Shot',
#        'Finger Roll Shot', 'Fadeaway Jump Shot', 'Follow Up Dunk Shot',
#        'Hook Shot', 'Turnaround Hook Shot', 'Running Tip Shot',
#        'Jump Hook Shot', 'Running Finger Roll Shot', 'Jump Bank Shot',
#        'Turnaround Finger Roll Shot', 'Hook Bank Shot',
#        'Driving Hook Shot', 'Running Reverse Layup Shot',
#        'Driving Finger Roll Layup Shot', 'Fadeaway Bank shot',
#        'Pullup Jump shot', 'Finger Roll Layup Shot',
#        'Turnaround Fadeaway shot', 'Driving Reverse Layup Shot',
#        'Driving Slam Dunk Shot', 'Step Back Jump shot',
#        'Reverse Slam Dunk Shot', 'Turnaround Bank shot',
#        'Running Finger Roll Layup Shot', 'Floating Jump shot',
#        'Putback Slam Dunk Shot', 'Running Bank shot', 'Driving Bank shot',
#        'Putback Layup Shot', 'Driving Jump shot', 'Putback Dunk Shot',
#        'Pullup Bank shot', 'Running Slam Dunk Shot', 'Cutting Layup Shot',
#        'Driving Floating Jump Shot', 'Running Pull-Up Jump Shot',
#        'Tip Layup Shot', 'Driving Floating Bank Jump Shot',
#        'Turnaround Fadeaway Bank Jump Shot',
#        'Cutting Finger Roll Layup Shot'], dtype=object)

# %%
not_needed.append('game_event_id')

# %%
not_needed
# Out:
# ['game_event_id']

# %%
not_needed.append('game_id')

# %%
sns.set_style('whitegrid')

# %%
sns.pairplot(df, vars=['loc_x', 'loc_y', 'lat', 'lon'], hue='shot_made_flag')

# %%
plt.show()

# %%
not_needed.extend(['lon', 'lat'])

# %%
df['time_remaining'] = 60 * df.loc[:, 'minutes_remaining'] + df.loc[:, 'seconds_remaining']

# %%
not_needed.extend(['minutes_remaining', 'seconds_remaining'])

# %%
not_needed
# Out:
# ['game_event_id',
#  'game_id',
#  'lon',
#  'lat',
#  'minutes_remaining',
#  'seconds_remaining']

# %%
df['season'] = df['season'].apply(lambda x: x[:4])
df['season'] = pd.to_numeric(df['season'])

# %%
df['3pt_goal'] = df['shot_type'].str.contains('3PT').astype('int')
not_needed.append('shot_type')

# %%
not_needed.append('shot_zone_range')

# %%
area_group = df.groupby('shot_zone_area')
basic_group = df.groupby('shot_zone_basic')

# %%
area_group

# %%
plt.subplots(1, 2, figsize=(15, 7), sharey=True)
colors = list('rgbcmyk')

plt.subplot(121)
plt.ylim(500, -50)
plt.title('shot_zone_area')
for i, (_, area) in enumerate(area_group):
    plt.scatter(area['loc_x'], area['loc_y'], alpha=0.1, color=colors[i])
    
plt.subplot(122)
plt.ylim(500, -50)
plt.title('shot_zone_basic')
for i, (_, basic) in enumerate(basic_group):
    plt.scatter(basic['loc_x'], basic['loc_y'], alpha=0.1, color=colors[i])

# %%
plt.show()

# %%
not_needed.extend(['team_id', 'team_name'])

# %%
df['game_date'] = pd.to_datetime(df['game_date'])
df['game_year'] = df['game_date'].dt.year
df['game_month'] = df['game_date'].dt.month
df['game_day'] = df['game_date'].dt.dayofweek

not_needed.append('game_date')

# %%
df['home_game'] = df['matchup'].str.contains('vs.').astype(int)
not_needed.append('matchup')

# %%
df.set_index('shot_id', inplace=True)

# %%
df = df.drop(not_needed, axis=1)

# %%
df.shape
# Out:
# (30697, 18)

# %%
df.head(10)
# Out:
#                action_type combined_shot_type  loc_x  loc_y  period  playoffs  \
# shot_id
# 1                Jump Shot          Jump Shot    167     72       1         0
# 2                Jump Shot          Jump Shot   -157      0       1         0
# 3                Jump Shot          Jump Shot   -101    135       1         0
# 4                Jump Shot          Jump Shot    138    175       1         0
# 5        Driving Dunk Shot               Dunk      0      0       2         0
# 6                Jump Shot          Jump Shot   -145    -11       3         0
# 7               Layup Shot              Layup      0      0       3         0
# 8                Jump Shot          Jump Shot      1     28       3         0
# 9                Jump Shot          Jump Shot    -65    108       3         0
# 10       Running Jump Shot          Jump Shot    -33    125       3         0
#
#          season  shot_distance  shot_made_flag         shot_zone_area  \
# shot_id
# 1          2000             18             NaN          Right Side(R)
# 2          2000             15             0.0           Left Side(L)
# 3          2000             16             1.0   Left Side Center(LC)
# 4          2000             22             0.0  Right Side Center(RC)
# 5          2000              0             1.0              Center(C)
# 6          2000             14             0.0           Left Side(L)
# 7          2000              0             1.0              Center(C)
# 8          2000              2             NaN              Center(C)
# 9          2000             12             1.0           Left Side(L)
# 10         2000             12             0.0              Center(C)
#
#                shot_zone_basic opponent  time_remaining  3pt_goal  game_year  \
# shot_id
# 1                    Mid-Range      POR             627         0       2000
# 2                    Mid-Range      POR             622         0       2000
# 3                    Mid-Range      POR             465         0       2000
# 4                    Mid-Range      POR             412         0       2000
# 5              Restricted Area      POR             379         0       2000
# 6                    Mid-Range      POR             572         0       2000
# 7              Restricted Area      POR             532         0       2000
# 8              Restricted Area      POR             485         0       2000
# 9        In The Paint (Non-RA)      POR             372         0       2000
# 10       In The Paint (Non-RA)      POR             216         0       2000
#
#          game_month  game_day  home_game
# shot_id
# 1                10         1          0
# 2                10         1          0
# 3                10         1          0
# 4                10         1          0
# 5                10         1          0
# 6                10         1          0
# 7                10         1          0
# 8                10         1          0
# 9                10         1          0
# 10               10         1          0

# %%
submission_data = df[df['shot_made_flag'].isnull()]
submission_data = submission_data.drop('shot_made_flag', 1)
submission_data.shape
# Out:
# (5000, 17)

# %%
submission_data.head()
# Out:
#                 action_type combined_shot_type  loc_x  loc_y  period  \
# shot_id
# 1                 Jump Shot          Jump Shot    167     72       1
# 8                 Jump Shot          Jump Shot      1     28       3
# 17       Driving Layup Shot              Layup      0      0       1
# 20       Driving Layup Shot              Layup      0      0       3
# 33                Jump Shot          Jump Shot    163     76       1
#
#          playoffs  season  shot_distance shot_zone_area  shot_zone_basic  \
# shot_id
# 1               0    2000             18  Right Side(R)        Mid-Range
# 8               0    2000              2      Center(C)  Restricted Area
# 17              0    2000              0      Center(C)  Restricted Area
# 20              0    2000              0      Center(C)  Restricted Area
# 33              0    2000             17  Right Side(R)        Mid-Range
#
#         opponent  time_remaining  3pt_goal  game_year  game_month  game_day  \
# shot_id
# 1            POR             627         0       2000          10         1
# 8            POR             485         0       2000          10         1
# 17           UTA               1         0       2000          11         2
# 20           UTA             646         0       2000          11         2
# 33           VAN             686         0       2000          11         5
#
#          home_game
# shot_id
# 1                0
# 8                0
# 17               1
# 20               1
# 33               0

# %%
data = df[df['shot_made_flag'].notnull()]
data.shape
# Out:
# (25697, 18)

# %%
sns.countplot(x='shot_made_flag', data=data)

# %%
plt.show()

# %%
data['shot_made_flag'].value_counts() / data['shot_made_flag'].shape
# Out:
# 0.0    0.553839
# 1.0    0.446161
# Name: shot_made_flag, dtype: float64

# %%
data['time_remaining'].plot(kind='hist', bins=24, xlim=(720, 0), figsize=(12,6),
                            title='Attempts made over time\n(seconds to the end of period)')

# %%
plt.show()

# %%
time_bins = np.arange(0, 721, 30)
attempts_in_time = pd.cut(data['time_remaining'], time_bins, right=False)
attempts_in_time
# Out:
# shot_id
# 2        [600, 630)
# 3        [450, 480)
# 4        [390, 420)
# 5        [360, 390)
# 6        [570, 600)
# 7        [510, 540)
# 9        [360, 390)
# 10       [210, 240)
# 11        [90, 120)
# 12       [660, 690)
# 13       [420, 450)
# 14       [150, 180)
# 15         [60, 90)
# 16         [30, 60)
# 18       [510, 540)
# 19       [660, 690)
# 21       [600, 630)
# 22       [540, 570)
# 23       [450, 480)
# 24       [330, 360)
# 25       [300, 330)
# 26       [150, 180)
# 27       [120, 150)
# 28         [30, 60)
# 29       [480, 510)
# 30       [360, 390)
# 31         [60, 90)
# 32         [30, 60)
# 39       [210, 240)
# 40          [0, 30)
#             ...
# 30662    [570, 600)
# 30663    [510, 540)
# 30664    [390, 420)
# 30666    [330, 360)
# 30667    [240, 270)
# 30668    [570, 600)
# 30670    [210, 240)
# 30671    [570, 600)
# 30672    [510, 540)
# 30673    [480, 510)
# 30674    [420, 450)
# 30675    [150, 180)
# 30676    [120, 150)
# 30677      [30, 60)
# 30678       [0, 30)
# 30679    [210, 240)
# 30680      [30, 60)
# 30682       [0, 30)
# 30684    [630, 660)
# 30685    [600, 630)
# 30686    [450, 480)
# 30688    [180, 210)
# 30689      [60, 90)
# 30690       [0, 30)
# 30691    [690, 720)
# 30692    [420, 450)
# 30693    [360, 390)
# 30695    [180, 210)
# 30696    [120, 150)
# 30697      [30, 60)
# Name: time_remaining, dtype: category
# Categories (24, object): [[0, 30) < [30, 60) < [60, 90) < [90, 120) ... [600, 630) < [630, 660) < [660, 690) < [690, 720)]

# %%
grouped = data.groupby(attempts_in_time)
prec = grouped['shot_made_flag'].mean()

# %%
prec
# Out:
# time_remaining
# [0, 30)       0.333695
# [30, 60)      0.441993
# [60, 90)      0.455326
# [90, 120)     0.438739
# [120, 150)    0.452632
# [150, 180)    0.441434
# [180, 210)    0.440999
# [210, 240)    0.461349
# [240, 270)    0.452736
# [270, 300)    0.451747
# [300, 330)    0.463605
# [330, 360)    0.468599
# [360, 390)    0.469574
# [390, 420)    0.470352
# [420, 450)    0.483871
# [450, 480)    0.479781
# [480, 510)    0.405163
# [510, 540)    0.465035
# [540, 570)    0.459916
# [570, 600)    0.500000
# [600, 630)    0.480790
# [630, 660)    0.428410
# [660, 690)    0.411953
# [690, 720)    0.441322
# Name: shot_made_flag, dtype: float64

# %%
prec[::-1].plot(kind='bar', figsize=(12, 6), ylim=(0.2, 0.5), 
                title='Shot accuracy over time\n(seconds to the end of period)')

# %%
plt.show()

# %%
ast_30 = data[data['time_remaining'] < 30]
last_30['shot_made_flag'].value_counts() / last_30['shot_made_flag'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-a8b05be3a178> in <module>()
#       1 ast_30 = data[data['time_remaining'] < 30]
# ----> 2 last_30['shot_made_flag'].value_counts() / last_30['shot_made_flag'].shape
#
# NameError: name 'last_30' is not defined

# %%
last_30 = data[data['time_remaining'] < 30]
last_30['shot_made_flag'].value_counts() / last_30['shot_made_flag'].shape
# Out:
# 0.0    0.666305
# 1.0    0.333695
# Name: shot_made_flag, dtype: float64

# %%
last_2min = data[data['time_remaining'] <= 120]

# %%
last_2min
# Out:
#                   action_type combined_shot_type  loc_x  loc_y  period  \
# shot_id
# 11                  Jump Shot          Jump Shot    -94    238       3
# 15                  Jump Shot          Jump Shot    -23     47       1
# 16                  Jump Shot          Jump Shot     62    192       1
# 28                  Jump Shot          Jump Shot   -183    186       3
# 31          Running Jump Shot          Jump Shot    121      4       4
# 32                  Jump Shot          Jump Shot    127     34       4
# 40                  Jump Shot          Jump Shot    -27    272       2
# 51                 Layup Shot              Layup      1      9       4
# 52                 Layup Shot              Layup    -12      9       4
# 62                 Layup Shot              Layup     22     49       2
# 64         Driving Layup Shot              Layup     56     21       3
# 65          Running Jump Shot          Jump Shot    121     26       3
# 75                  Jump Shot          Jump Shot    167    190       2
# 79                  Jump Shot          Jump Shot    -71     42       3
# 82                  Jump Shot          Jump Shot      1    156       4
# 90       Turnaround Jump Shot          Jump Shot    140      0       1
# 91                  Jump Shot          Jump Shot     -1    156       1
# 92                  Jump Shot          Jump Shot   -151      4       1
# 98                  Jump Shot          Jump Shot   -193    150       2
# 99                  Jump Shot          Jump Shot    140      0       2
# 106                 Jump Shot          Jump Shot   -193     42       3
# 107                 Jump Shot          Jump Shot   -166     55       3
# 119        Driving Layup Shot              Layup      0      0       1
# 120                 Jump Shot          Jump Shot     85    141       1
# 124         Running Hook Shot          Hook Shot      0      0       2
# 125                 Jump Shot          Jump Shot      1    276       2
# 135                 Jump Shot          Jump Shot   -119    133       3
# 140         Running Jump Shot          Jump Shot      9     59       4
# 142                  Tip Shot           Tip Shot      0      0       4
# 147                 Jump Shot          Jump Shot    -98     97       1
# ...                       ...                ...    ...    ...     ...
# 30575               Jump Shot          Jump Shot     -3    589       2
# 30579               Jump Shot          Jump Shot    184     40       3
# 30580               Jump Shot          Jump Shot   -199    194       3
# 30585               Jump Shot          Jump Shot   -184    166       4
# 30586               Jump Shot          Jump Shot   -113    235       4
# 30587               Jump Shot          Jump Shot   -220    156       4
# 30588               Jump Shot          Jump Shot   -227    115       4
# 30592               Jump Shot          Jump Shot    -98    261       1
# 30593       Running Jump Shot          Jump Shot      1     72       1
# 30597               Jump Shot          Jump Shot   -192     93       2
# 30598          Slam Dunk Shot               Dunk      0      0       2
# 30600               Jump Shot          Jump Shot    -21    205       3
# 30607               Jump Shot          Jump Shot    -63    149       4
# 30613               Jump Shot          Jump Shot    158    497       1
# 30619       Running Jump Shot          Jump Shot     29    128       3
# 30620               Jump Shot          Jump Shot    143    205       4
# 30640               Jump Shot          Jump Shot     -6     78       3
# 30641               Jump Shot          Jump Shot    108     57       3
# 30645               Jump Shot          Jump Shot      1    151       4
# 30648               Jump Shot          Jump Shot      1    231       5
# 30650                Tip Shot           Tip Shot      1     12       5
# 30655               Jump Shot          Jump Shot    201     12       1
# 30676               Jump Shot          Jump Shot   -134    216       1
# 30677       Running Jump Shot          Jump Shot   -141      0       1
# 30678               Jump Shot          Jump Shot   -113    143       1
# 30680              Layup Shot              Layup      0      0       2
# 30682               Jump Shot          Jump Shot    -18    261       2
# 30689               Jump Shot          Jump Shot   -126     61       3
# 30690               Jump Shot          Jump Shot    -12    679       3
# 30697               Jump Shot          Jump Shot      1     72       4
#
#          playoffs  season  shot_distance  shot_made_flag  \
# shot_id
# 11              0    2000             25             0.0
# 15              0    2000              5             0.0
# 16              0    2000             20             0.0
# 28              0    2000             26             0.0
# 31              0    2000             12             1.0
# 32              0    2000             13             0.0
# 40              0    2000             27             1.0
# 51              0    2000              0             0.0
# 52              0    2000              1             0.0
# 62              0    2000              5             1.0
# 64              0    2000              5             0.0
# 65              0    2000             12             1.0
# 75              0    2000             25             0.0
# 79              0    2000              8             0.0
# 82              0    2000             15             0.0
# 90              0    2000             14             1.0
# 91              0    2000             15             1.0
# 92              0    2000             15             1.0
# 98              0    2000             24             0.0
# 99              0    2000             14             1.0
# 106             0    2000             19             0.0
# 107             0    2000             17             0.0
# 119             0    2000              0             1.0
# 120             0    2000             16             0.0
# 124             0    2000              0             1.0
# 125             0    2000             27             1.0
# 135             0    2000             17             0.0
# 140             0    2000              5             1.0
# 142             0    2000              0             0.0
# 147             0    2000             13             1.0
# ...           ...     ...            ...             ...
# 30575           1    1999             58             0.0
# 30579           1    1999             18             1.0
# 30580           1    1999             27             1.0
# 30585           1    1999             24             1.0
# 30586           1    1999             26             0.0
# 30587           1    1999             26             1.0
# 30588           1    1999             25             0.0
# 30592           1    1999             27             0.0
# 30593           1    1999              7             0.0
# 30597           1    1999             21             1.0
# 30598           1    1999              0             1.0
# 30600           1    1999             20             1.0
# 30607           1    1999             16             1.0
# 30613           1    1999             52             0.0
# 30619           1    1999             13             1.0
# 30620           1    1999             24             0.0
# 30640           1    1999              7             1.0
# 30641           1    1999             12             0.0
# 30645           1    1999             15             1.0
# 30648           1    1999             23             1.0
# 30650           1    1999              1             1.0
# 30655           1    1999             20             0.0
# 30676           1    1999             25             0.0
# 30677           1    1999             14             1.0
# 30678           1    1999             18             0.0
# 30680           1    1999              0             0.0
# 30682           1    1999             26             1.0
# 30689           1    1999             13             1.0
# 30690           1    1999             67             0.0
# 30697           1    1999              7             0.0
#
#                 shot_zone_area        shot_zone_basic opponent  \
# shot_id
# 11        Left Side Center(LC)      Above the Break 3      POR
# 15                   Center(C)  In The Paint (Non-RA)      UTA
# 16                   Center(C)              Mid-Range      UTA
# 28        Left Side Center(LC)      Above the Break 3      UTA
# 31               Right Side(R)              Mid-Range      UTA
# 32               Right Side(R)              Mid-Range      UTA
# 40                   Center(C)      Above the Break 3      VAN
# 51                   Center(C)        Restricted Area      VAN
# 52                   Center(C)        Restricted Area      VAN
# 62                   Center(C)  In The Paint (Non-RA)      LAC
# 64                   Center(C)  In The Paint (Non-RA)      LAC
# 65               Right Side(R)              Mid-Range      LAC
# 75       Right Side Center(RC)      Above the Break 3      HOU
# 79                Left Side(L)  In The Paint (Non-RA)      HOU
# 82                   Center(C)              Mid-Range      HOU
# 90               Right Side(R)              Mid-Range      SAS
# 91                   Center(C)              Mid-Range      SAS
# 92                Left Side(L)              Mid-Range      SAS
# 98        Left Side Center(LC)      Above the Break 3      SAS
# 99               Right Side(R)              Mid-Range      SAS
# 106               Left Side(L)              Mid-Range      SAS
# 107               Left Side(L)              Mid-Range      SAS
# 119                  Center(C)        Restricted Area      HOU
# 120      Right Side Center(RC)              Mid-Range      HOU
# 124                  Center(C)        Restricted Area      HOU
# 125                  Center(C)      Above the Break 3      HOU
# 135       Left Side Center(LC)              Mid-Range      HOU
# 140                  Center(C)  In The Paint (Non-RA)      HOU
# 142                  Center(C)        Restricted Area      HOU
# 147               Left Side(L)              Mid-Range      DEN
# ...                        ...                    ...      ...
# 30575           Back Court(BC)              Backcourt      POR
# 30579            Right Side(R)              Mid-Range      POR
# 30580     Left Side Center(LC)      Above the Break 3      POR
# 30585     Left Side Center(LC)      Above the Break 3      POR
# 30586     Left Side Center(LC)      Above the Break 3      POR
# 30587     Left Side Center(LC)      Above the Break 3      POR
# 30588     Left Side Center(LC)      Above the Break 3      POR
# 30592     Left Side Center(LC)      Above the Break 3      POR
# 30593                Center(C)  In The Paint (Non-RA)      POR
# 30597             Left Side(L)              Mid-Range      POR
# 30598                Center(C)        Restricted Area      POR
# 30600                Center(C)              Mid-Range      POR
# 30607     Left Side Center(LC)              Mid-Range      POR
# 30613           Back Court(BC)              Backcourt      IND
# 30619                Center(C)  In The Paint (Non-RA)      IND
# 30620    Right Side Center(RC)      Above the Break 3      IND
# 30640                Center(C)  In The Paint (Non-RA)      IND
# 30641            Right Side(R)              Mid-Range      IND
# 30645                Center(C)              Mid-Range      IND
# 30648                Center(C)              Mid-Range      IND
# 30650                Center(C)        Restricted Area      IND
# 30655            Right Side(R)              Mid-Range      IND
# 30676     Left Side Center(LC)      Above the Break 3      IND
# 30677             Left Side(L)              Mid-Range      IND
# 30678     Left Side Center(LC)              Mid-Range      IND
# 30680                Center(C)        Restricted Area      IND
# 30682                Center(C)      Above the Break 3      IND
# 30689             Left Side(L)              Mid-Range      IND
# 30690           Back Court(BC)              Backcourt      IND
# 30697                Center(C)  In The Paint (Non-RA)      IND
#
#          time_remaining  3pt_goal  game_year  game_month  game_day  home_game
# shot_id
# 11                  116         1       2000          10         1          0
# 15                   76         0       2000          11         2          1
# 16                   48         0       2000          11         2          1
# 28                   30         1       2000          11         2          1
# 31                   80         0       2000          11         2          1
# 32                   30         0       2000          11         2          1
# 40                    4         1       2000          11         5          0
# 51                   68         0       2000          11         5          0
# 52                   66         0       2000          11         5          0
# 62                   47         0       2000          11         6          1
# 64                   37         0       2000          11         6          1
# 65                    1         0       2000          11         6          1
# 75                   10         1       2000          11         1          0
# 79                    1         0       2000          11         1          0
# 82                   46         0       2000          11         1          0
# 90                  108         0       2000          11         2          0
# 91                   85         0       2000          11         2          0
# 92                   47         0       2000          11         2          0
# 98                   53         1       2000          11         2          0
# 99                   48         0       2000          11         2          0
# 106                  48         0       2000          11         2          0
# 107                  21         0       2000          11         2          0
# 119                  44         0       2000          11         6          1
# 120                  21         0       2000          11         6          1
# 124                  30         0       2000          11         6          1
# 125                   4         1       2000          11         6          1
# 135                  14         0       2000          11         6          1
# 140                  98         0       2000          11         6          1
# 142                  63         0       2000          11         6          1
# 147                  48         0       2000          11         1          1
# ...                 ...       ...        ...         ...       ...        ...
# 30575                 0         1       2000           6         4          0
# 30579                78         0       2000           6         4          0
# 30580                 1         1       2000           6         4          0
# 30585               110         1       2000           6         4          0
# 30586                81         1       2000           6         4          0
# 30587                40         1       2000           6         4          0
# 30588                29         1       2000           6         4          0
# 30592                82         1       2000           6         6          1
# 30593                24         0       2000           6         6          1
# 30597               109         0       2000           6         6          1
# 30598                 4         0       2000           6         6          1
# 30600                37         0       2000           6         6          1
# 30607                69         0       2000           6         6          1
# 30613                 0         1       2000           6         2          1
# 30619                25         0       2000           6         2          1
# 30620                26         1       2000           6         2          1
# 30640                51         0       2000           6         2          0
# 30641                 0         0       2000           6         2          0
# 30645                99         0       2000           6         2          0
# 30648                80         0       2000           6         2          0
# 30650                 5         0       2000           6         2          0
# 30655                76         0       2000           6         4          0
# 30676               120         1       2000           6         0          1
# 30677                37         0       2000           6         0          1
# 30678                 1         0       2000           6         0          1
# 30680                41         0       2000           6         0          1
# 30682                 2         1       2000           6         0          1
# 30689                67         0       2000           6         0          1
# 30690                 0         1       2000           6         0          1
# 30697                39         0       2000           6         0          1
#
# [5575 rows x 18 columns]

# %%
last_2min['time_remaining']
# Out:
# shot_id
# 11       116
# 15        76
# 16        48
# 28        30
# 31        80
# 32        30
# 40         4
# 51        68
# 52        66
# 62        47
# 64        37
# 65         1
# 75        10
# 79         1
# 82        46
# 90       108
# 91        85
# 92        47
# 98        53
# 99        48
# 106       48
# 107       21
# 119       44
# 120       21
# 124       30
# 125        4
# 135       14
# 140       98
# 142       63
# 147       48
#         ...
# 30575      0
# 30579     78
# 30580      1
# 30585    110
# 30586     81
# 30587     40
# 30588     29
# 30592     82
# 30593     24
# 30597    109
# 30598      4
# 30600     37
# 30607     69
# 30613      0
# 30619     25
# 30620     26
# 30640     51
# 30641      0
# 30645     99
# 30648     80
# 30650      5
# 30655     76
# 30676    120
# 30677     37
# 30678      1
# 30680     41
# 30682      2
# 30689     67
# 30690      0
# 30697     39
# Name: time_remaining, dtype: int64

# %%
last_2min['time_remaining'].plot(kind='hist', bins=30, xlim=(120, 0), figsize=(12,6),
                            title='Attempts made over time\n(seconds to the end of period)')

# %%
plt.show()

# %%
last_5sec_misses = data[(data['time_remaining'] <= 5) & (data['shot_made_flag'] == 0)]
last_5sec_scores = data[(data['time_remaining'] <= 5) & (data['shot_made_flag'] == 1)]


fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(12,7))
ax1.set_ylim(800, -50)

sns.regplot(x='loc_x', y='loc_y', data=last_5sec_misses, fit_reg=False, ax=ax1, color='r')
sns.regplot(x='loc_x', y='loc_y', data=last_5sec_scores, fit_reg=False, ax=ax2, color='g')

# %%
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="period", hue="shot_made_flag", data=data)

# %%
plt.show()

# %%
period_acc = data['shot_made_flag'].groupby(data['period']).mean()
period_acc.plot(kind='barh', figsize=(12, 6))

# %%
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="combined_shot_type", hue="shot_made_flag", data=data)
plt.show()

# %%
shot_type_acc = data['shot_made_flag'].groupby(data['combined_shot_type']).mean()
shot_type_acc.plot(kind='barh', figsize=(12, 6))

# %%
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="season", hue="shot_made_flag", data=data)
plt.show()

# %%
distance_bins = np.append(np.arange(0, 31, 3), 300) 
distance_cat = pd.cut(data['shot_distance'], distance_bins, right=False)
distance_cat
# Out:
# shot_id
# 2         [15, 18)
# 3         [15, 18)
# 4         [21, 24)
# 5           [0, 3)
# 6         [12, 15)
# 7           [0, 3)
# 9         [12, 15)
# 10        [12, 15)
# 11        [24, 27)
# 12        [15, 18)
# 13        [12, 15)
# 14         [9, 12)
# 15          [3, 6)
# 16        [18, 21)
# 18        [24, 27)
# 19        [15, 18)
# 21        [12, 15)
# 22        [18, 21)
# 23         [9, 12)
# 24        [18, 21)
# 25          [6, 9)
# 26          [0, 3)
# 27        [18, 21)
# 28        [24, 27)
# 29        [18, 21)
# 30          [6, 9)
# 31        [12, 15)
# 32        [12, 15)
# 39        [18, 21)
# 40        [27, 30)
#            ...
# 30662       [0, 3)
# 30663       [3, 6)
# 30664      [9, 12)
# 30666       [0, 3)
# 30667     [18, 21)
# 30668     [24, 27)
# 30670     [15, 18)
# 30671       [6, 9)
# 30672       [0, 3)
# 30673      [9, 12)
# 30674      [9, 12)
# 30675     [24, 27)
# 30676     [24, 27)
# 30677     [12, 15)
# 30678     [18, 21)
# 30679       [0, 3)
# 30680       [0, 3)
# 30682     [24, 27)
# 30684     [21, 24)
# 30685     [12, 15)
# 30686     [24, 27)
# 30688      [9, 12)
# 30689     [12, 15)
# 30690    [30, 300)
# 30691     [15, 18)
# 30692       [0, 3)
# 30693       [3, 6)
# 30695     [21, 24)
# 30696     [24, 27)
# 30697       [6, 9)
# Name: shot_distance, dtype: category
# Categories (11, object): [[0, 3) < [3, 6) < [6, 9) < [9, 12) ... [21, 24) < [24, 27) < [27, 30) < [30, 300)]

# %%
dist_data = data.loc[:, ['shot_distance', 'shot_made_flag']]

# %%
dist_data
# Out:
#          shot_distance  shot_made_flag
# shot_id
# 2                   15             0.0
# 3                   16             1.0
# 4                   22             0.0
# 5                    0             1.0
# 6                   14             0.0
# 7                    0             1.0
# 9                   12             1.0
# 10                  12             0.0
# 11                  25             0.0
# 12                  17             1.0
# 13                  12             1.0
# 14                   9             0.0
# 15                   5             0.0
# 16                  20             0.0
# 18                  25             1.0
# 19                  16             0.0
# 21                  14             0.0
# 22                  18             0.0
# 23                  11             1.0
# 24                  18             1.0
# 25                   7             1.0
# 26                   0             0.0
# 27                  20             0.0
# 28                  26             0.0
# 29                  19             0.0
# 30                   8             0.0
# 31                  12             1.0
# 32                  13             0.0
# 39                  20             1.0
# 40                  27             1.0
# ...                ...             ...
# 30662                0             1.0
# 30663                5             0.0
# 30664               10             0.0
# 30666                2             0.0
# 30667               18             0.0
# 30668               25             0.0
# 30670               17             0.0
# 30671                7             0.0
# 30672                0             0.0
# 30673               10             1.0
# 30674               11             0.0
# 30675               24             1.0
# 30676               25             0.0
# 30677               14             1.0
# 30678               18             0.0
# 30679                2             0.0
# 30680                0             0.0
# 30682               26             1.0
# 30684               21             0.0
# 30685               13             0.0
# 30686               26             0.0
# 30688               10             0.0
# 30689               13             1.0
# 30690               67             0.0
# 30691               15             0.0
# 30692                0             0.0
# 30693                4             0.0
# 30695               21             1.0
# 30696               26             0.0
# 30697                7             0.0
#
# [25697 rows x 2 columns]

# %%
dist_data['distance_cat'] = distance_cat

distance_cat.value_counts(sort=False)
# Out:
# [0, 3)       5613
# [3, 6)       1080
# [6, 9)       1728
# [9, 12)      1718
# [12, 15)     2324
# [15, 18)     3362
# [18, 21)     3319
# [21, 24)     1735
# [24, 27)     3954
# [27, 30)      683
# [30, 300)     181
# Name: shot_distance, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x="shot_zone_area", hue="shot_made_flag", data=data)

# %%
plt.show()

# %%
plt.figure(figsize=(12,16))
sns.countplot(y="opponent", hue="shot_made_flag", data=data)

# %%
plt.show()
